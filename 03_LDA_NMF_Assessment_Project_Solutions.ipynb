# %% [markdown]
# <a href="https://colab.research.google.com/github/Evandro72/topicmodeling_NMF/blob/main/03_LDA_NMF_Assessment_Project_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Topic Modeling Assessment Project

# %% [markdown]
# #### Task: Import pandas and read in the quora_questions.csv file.

# %%
import pandas as pd

# %%
uj = pd.read_csv(f'Cleaned_text_Final_2.csv', lineterminator='\n')

# %%
uj = pd.read_csv('Cleaned_text_Final_2.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-101-229e2bdd5a7b> in <cell line: 1>()
# ----> 1 uj = pd.read_csv('Cleaned_text_Final_2.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
uj.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                       Date             User  \
# 0             0           0  2022-09-22 14:47:00+00:00   UmbriaJazz_OFC
# 1             1           1  2022-09-20 10:59:04+00:00         mbriotti
# 2             2           2  2022-09-19 23:27:59+00:00        GaffeBrio
# 3             3           3  2022-09-19 18:36:14+00:00       terninrete
# 4             4           4  2022-09-19 18:35:33+00:00  lorenzoniadrian
#
#                                                Tweet  \
# 0  About last night ✨\n#ujweekend \n\n@mariobiond...
# 1  A Perugia c’è la Rotatoria Miles Davis… viva @...
# 2  @UmbriaJazz_OFC Come vedete, a Terni si fa sem...
# 3  Terni: Umbria Jazz chiude alla grande con l’ex...
# 4  Terni: Umbria Jazz chiude alla grande con l’ex...
#
#                                         Cleaned_text
# 0  About last night \nujweekend \n\nmariobiondi h...
# 1  A Perugia c la Rotatoria Miles Davis viva Umbr...
# ...

# %% [markdown]
# # Preprocessing
#
# #### Task: Use TF-IDF Vectorization to create a vectorized document term matrix. You may want to explore the max_df and min_df parameters.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')

# %%
dtm = tfidf.fit_transform(uj['Cleaned_text'])

# %%
dtm
# Out:
# <25055x14094 sparse matrix of type '<class 'numpy.float64'>'
# 	with 273415 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Non-negative Matrix Factorization
#
# #### TASK: Using Scikit-Learn create an instance of NMF with 20 expected components. (Use random_state=42)..

# %%
from sklearn.decomposition import NMF

# %%
nmf_model = NMF(n_components=20,random_state=42)

# %%
nmf_model.fit(dtm)
# Out:
# NMF(n_components=20, random_state=42)

# %%
tfidf.get_feature_names_out()[1500]
# Out:
# 'bassista'

# %% [markdown]
# #### NAO RODA - TASK: Print our the top 15 most common words for each of the 20 topics.

# %%
for index,topic in enumerate(nmf_model.components_):
    print(f'THE TOP 10 WORDS FOR TOPIC #{index}')
    print([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# THE TOP 10 WORDS FOR TOPIC #0
# ['stasera', '2013', 'uj13', 'funk', 'cheektocheektour', 'days', 'uj12', 'sting', 'funkoff', 'umbriajazz']
#
#
# THE TOP 10 WORDS FOR TOPIC #1
# ['ansait', 'winter', 'italy', 'musica', '2013', 'terni', 'music', 'festival', 'jazz', 'umbria']
#
#
# THE TOP 10 WORDS FOR TOPIC #2
# ['comuneperugia', 'grande', 'umbriatourism', 'stefanobollani', 'uj16', 'thanks', 'great', 'mikasounds', 'grazie', 'umbriajazzofc']
#
#
# THE TOP 10 WORDS FOR TOPIC #3
# ['oggi', 'tutti', 'gli', 'grande', 'una', 'al', 'foto', 'concerto', 'le', 'di']
#
#
# THE TOP 10 WORDS FOR TOPIC #4
# ['today', 'july', '2015', 'italia', 'storico', 'music', 'summer', 'centro', 'italy', 'perugia']
#
#
# THE TOP 10 WORDS FOR TOPIC #5
# ['dellarena', 'amp', 'stadio', 'uj13', '13', 'concerto', 'allarena', 'arena', 'giuliana', 'santa']
#
#
# THE TOP 10 WORDS FOR TOPIC #6
# ['uj16', 'dellarena', 'insieme', 'flavioboltro', 'gazz', 'britti', 'katch', 'anche', 'sul', 'palco']
#
#
# ...

# %% [markdown]
# #### TASK: Add a new column to the original quora dataframe that labels each question into one of the 20 topic categories.

# %%
uj.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                       Date             User  \
# 0             0           0  2022-09-22 14:47:00+00:00   UmbriaJazz_OFC
# 1             1           1  2022-09-20 10:59:04+00:00         mbriotti
# 2             2           2  2022-09-19 23:27:59+00:00        GaffeBrio
# 3             3           3  2022-09-19 18:36:14+00:00       terninrete
# 4             4           4  2022-09-19 18:35:33+00:00  lorenzoniadrian
#
#                                                Tweet  \
# 0  About last night ✨\n#ujweekend \n\n@mariobiond...
# 1  A Perugia c’è la Rotatoria Miles Davis… viva @...
# 2  @UmbriaJazz_OFC Come vedete, a Terni si fa sem...
# 3  Terni: Umbria Jazz chiude alla grande con l’ex...
# 4  Terni: Umbria Jazz chiude alla grande con l’ex...
#
#                                         Cleaned_text
# 0  About last night \nujweekend \n\nmariobiondi h...
# 1  A Perugia c la Rotatoria Miles Davis viva Umbr...
# ...

# %%
topic_results = nmf_model.transform(dtm)

# %%
topic_results.argmax(axis=1)

uj['Topic'] = topic_results.argmax(axis=1)

uj.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0                       Date             User  \
# 0             0           0  2022-09-22 14:47:00+00:00   UmbriaJazz_OFC
# 1             1           1  2022-09-20 10:59:04+00:00         mbriotti
# 2             2           2  2022-09-19 23:27:59+00:00        GaffeBrio
# 3             3           3  2022-09-19 18:36:14+00:00       terninrete
# 4             4           4  2022-09-19 18:35:33+00:00  lorenzoniadrian
# 5             5           5  2022-09-19 07:16:58+00:00   UmbriaJazz_OFC
# 6             6           6  2022-09-18 18:10:03+00:00          Atmo_IT
# 7             7           7  2022-09-18 13:37:29+00:00            Boxol
# 8             8           8  2022-09-18 10:31:48+00:00         umbriaOn
# 9             9           9  2022-09-18 08:37:27+00:00   UmbriaJazz_OFC
#
#                                                Tweet  \
# 0  About last night ✨\n#ujweekend \n\n@mariobiond...
# 1  A Perugia c’è la Rotatoria Miles Davis… viva @...
# ...

# %%
uj.to_csv('topic_model.uj.csv')

# %% [markdown]
# # Great job!
