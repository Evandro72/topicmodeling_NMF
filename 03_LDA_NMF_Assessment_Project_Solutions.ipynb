# %% [markdown]
# <a href="https://colab.research.google.com/github/Evandro72/topicmodeling_NMF/blob/main/03_LDA_NMF_Assessment_Project_Solutions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Topic Modeling Assessment Project

# %% [markdown]
# #### Task: Import pandas and read in the quora_questions.csv file.

# %%
import pandas as pd

# %%
uj = pd.read_csv('tweetsUmbriajazzScraped.csv')

# %%
uj.head()
# Out:
#    Unnamed: 0                       Date             User  \
# 0           0  2022-09-22 14:47:00+00:00   UmbriaJazz_OFC
# 1           1  2022-09-20 10:59:04+00:00         mbriotti
# 2           2  2022-09-19 23:27:59+00:00        GaffeBrio
# 3           3  2022-09-19 18:36:14+00:00       terninrete
# 4           4  2022-09-19 18:35:33+00:00  lorenzoniadrian
#
#                                                Tweet
# 0  About last night ✨\n#ujweekend \n\n@mariobiond...
# 1  A Perugia c’è la Rotatoria Miles Davis… viva @...
# 2  @UmbriaJazz_OFC Come vedete, a Terni si fa sem...
# 3  Terni: Umbria Jazz chiude alla grande con l’ex...
# 4  Terni: Umbria Jazz chiude alla grande con l’ex...

# %% [markdown]
# # Preprocessing
#
# #### Task: Use TF-IDF Vectorization to create a vectorized document term matrix. You may want to explore the max_df and min_df parameters.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_df=0.95, min_df=2, stop_words='english')

# %%
dtm = tfidf.fit_transform(uj['Tweet'])

# %%
dtm
# Out:
# <25055x14094 sparse matrix of type '<class 'numpy.float64'>'
# 	with 273415 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Non-negative Matrix Factorization
#
# #### TASK: Using Scikit-Learn create an instance of NMF with 20 expected components. (Use random_state=42)..

# %%
from sklearn.decomposition import NMF

# %%
nmf_model = NMF(n_components=20,random_state=42)

# %%
nmf_model.fit(dtm)
# Out:
# NMF(n_components=20, random_state=42)

# %%
tfidf.get_feature_names_out()[1500]
# Out:
# 'barton'

# %% [markdown]
# #### NAO RODA - TASK: Print our the top 15 most common words for each of the 20 topics.

# %%
for index,topic in enumerate(nmf_model.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([tfidf.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['video', 'ujw22', '2013', '2014', 'uj', '2015', 'uj15', 'uj13', 'uj14', 'http']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['tickets', 'info', '2016', 'terni', 'uj18', '2017', '2018', 'uj17', 'uj16', 'https']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['funk', 'stasera', 'uj', 'ad', 'cheektocheektour', 'days', 'uj12', 'sting', 'funkoff', 'umbriajazz']
#
#
# THE TOP 15 WORDS FOR TOPIC #3
# ['13', 'agenda', 'italy', 'terni', '2013', 'winter', 'music', 'festival', 'jazz', 'umbria']
#
#
# THE TOP 15 WORDS FOR TOPIC #4
# ['gli', 'oggi', 'anni', 'una', 'al', 'edizione', 'foto', 'concerto', 'le', 'di']
#
#
# THE TOP 15 WORDS FOR TOPIC #5
# ['love', 'italia', 'storico', 'july', 'music', '2015', 'summer', 'centro', 'italy', 'perugia']
#
#
# THE TOP 15 WORDS FOR TOPIC #6
# ['uj14', '21', 'uj13', 'luglio', 'dell', 'concerto', '13', 'arena', 'santa', 'giuliana']
#
#
# THE TOP 15 WORDS FOR TOPIC #7
# ['umbriatourism', 'thanks', 'casaranolive', 'signorilemirko', 'stefanobollani', 'great', 'mikasounds', 'negramaro', 'grazie', 'umbriajazz_ofc']
#
#
# THE TOP 15 WORDS FOR TOPIC #8
# ['della', 'dei', 'ecco', 'giorno', 'suo', 'concerto', 'completo', 'del', 'programma', 'il']
#
#
# THE TOP 15 WORDS FOR TOPIC #9
# ['https', 'insieme', 'flavio', 'boltro', 'britti', 'gazzè', 'katchè', 'anche', 'sul', 'palco']
#
#
# THE TOP 15 WORDS FOR TOPIC #10
# ['cheektocheek', 'notice', 'pls', 'castelechelon', 'littlemonsters', 'cheektocheektour', 'love', 'tonybennett', 'itstonybennett', 'ladygaga']
#
#
# THE TOP 15 WORDS FOR TOPIC #11
# ['20', 'ujw23', 'ujw22', '28', 'gennaio', 'dal', 'al', 'dicembre', 'winter', 'orvieto']
#
#
# THE TOP 15 WORDS FOR TOPIC #12
# ['batiste', 'robert', 'glasper', 'trio', 'su', 'music', 'subsonica', 'periscope', 'uj15', 'live']
#
#
# THE TOP 15 WORDS FOR TOPIC #13
# ['jazzconvention', 'jjdhviawwa', 'trvq5d9ur5', 'orcugo0r3h', 'today', 'jazz', 'stories', 'jam', 'italian', 'magazine']
#
#
# THE TOP 15 WORDS FOR TOPIC #14
# ['music', 'solidarietà', 'buona', 'italia', 'concerti', 'giorni', 'eventi', 'della', 'grande', 'musica']
#
#
# THE TOP 15 WORDS FOR TOPIC #15
# ['partita', 'band', 'volta', 'serata', 'dei', 'della', 'sua', 'prima', 'del', 'la']
#
#
# THE TOP 15 WORDS FOR TOPIC #16
# ['pietro', 'oggi', 'ft', 'teatroeliseo', '21', 'repubblica', 'repubblicait', 'speciale', 'rt', 'webnotte']
#
#
# THE TOP 15 WORDS FOR TOPIC #17
# ['anno', 'grazie', 'sono', 'una', 'ma', 'ci', 'si', 'da', 'non', 'che']
#
#
# THE TOP 15 WORDS FOR TOPIC #18
# ['conte', 'cheek', 'bennet', '2015', 'amp', 'arringatore', 'bennett', 'tony', 'gaga', 'lady']
#
#
# THE TOP 15 WORDS FOR TOPIC #19
# ['17', '10', 'uj', '13', '16', 'amp', '12', '15', 'al', 'luglio']

# %% [markdown]
# #### TASK: Add a new column to the original quora dataframe that labels each question into one of the 20 topic categories.

# %%
uj.head()
# Out:
#    Unnamed: 0                       Date             User  \
# 0           0  2022-09-22 14:47:00+00:00   UmbriaJazz_OFC
# 1           1  2022-09-20 10:59:04+00:00         mbriotti
# 2           2  2022-09-19 23:27:59+00:00        GaffeBrio
# 3           3  2022-09-19 18:36:14+00:00       terninrete
# 4           4  2022-09-19 18:35:33+00:00  lorenzoniadrian
#
#                                                Tweet
# 0  About last night ✨\n#ujweekend \n\n@mariobiond...
# 1  A Perugia c’è la Rotatoria Miles Davis… viva @...
# 2  @UmbriaJazz_OFC Come vedete, a Terni si fa sem...
# 3  Terni: Umbria Jazz chiude alla grande con l’ex...
# 4  Terni: Umbria Jazz chiude alla grande con l’ex...

# %%
topic_results = nmf_model.transform(dtm)

# %%
topic_results.argmax(axis=1)

uj['Topic'] = topic_results.argmax(axis=1)

uj.head(10)
# Out:
#    Unnamed: 0                       Date             User  \
# 0           0  2022-09-22 14:47:00+00:00   UmbriaJazz_OFC
# 1           1  2022-09-20 10:59:04+00:00         mbriotti
# 2           2  2022-09-19 23:27:59+00:00        GaffeBrio
# 3           3  2022-09-19 18:36:14+00:00       terninrete
# 4           4  2022-09-19 18:35:33+00:00  lorenzoniadrian
# 5           5  2022-09-19 07:16:58+00:00   UmbriaJazz_OFC
# 6           6  2022-09-18 18:10:03+00:00          Atmo_IT
# 7           7  2022-09-18 13:37:29+00:00            Boxol
# 8           8  2022-09-18 10:31:48+00:00         umbriaOn
# 9           9  2022-09-18 08:37:27+00:00   UmbriaJazz_OFC
#
#                                                Tweet  Topic
# 0  About last night ✨\n#ujweekend \n\n@mariobiond...      1
# 1  A Perugia c’è la Rotatoria Miles Davis… viva @...     15
# 2  @UmbriaJazz_OFC Come vedete, a Terni si fa sem...      8
# 3  Terni: Umbria Jazz chiude alla grande con l’ex...      3
# 4  Terni: Umbria Jazz chiude alla grande con l’ex...      3
# 5  GRAZIE 💛\n#ujweekend22\n\nSee you in Orvieto ❄...     11
# 6  @UmbriaJazz_OFC - Terni\nPalco by #Atmo 🌪🥰 htt...      9
# 7  Il mondo dovrebbe essere una street band ❤️\nB...      8
# 8  #Terni, sold out per #DeSica ad #UmbriaJazz We...      4
# 9  Umbria Jazz Weekend☀️DAY 4\n#ujweekend22\n\nIN...      1

# %%
uj.to_csv('topic_model.uj.csv')

# %% [markdown]
# # Great job!
